# %% [markdown]
# <a href="https://colab.research.google.com/github/ndenizkoroglu/-automation-test-repo/blob/main/Untitled0_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.listdir("/content/drive/MyDrive")
# Out:
# ['Colab Notebooks',
#  'Classroom',
#  'sebahat hoca d.pptx',
#  'NisaDeniz Köroğlu.pptx',
#  'nisadenizköroğlu 1.pdf',
#  'nisadenizköroğlu makale inceleme formu.pdf',
#  'matematik eğitimi bağlamında matematik tarihi çalışmalarına genel bir bakış bir meta sentez çalışması.pdf',
#  'NİSA DENİZ KÖROĞLU.pdf',
#  'sales.csv',
#  'customers.csv',
#  'customers (2).gsheet',
#  'VERİ',
#  'analysis.gsheet',
#  'sales (7).gsheet',
#  'customers (1).gsheet',
#  'yeni veri customers.gsheet',
#  'denizkoroglu.gsheet',
#  'sales (6).gsheet',
#  'sales (5).gsheet',
#  'products (1).csv',
#  'customers.gsheet',
#  'products.gsheet',
#  'sales (4).gsheet',
#  'Başlıksız e-tablo (2).gsheet',
#  'Başlıksız e-tablo (1).gsheet',
#  'sales (2).csv',
#  'sales (3).gsheet',
#  'sales (1).gsheet',
#  'sales.gsheet',
#  'sales (2) (1).gsheet',
#  'sales (2).gsheet',
#  'Başlıksız e-tablo.gsheet',
#  'products (2).csv',
#  'products (1) (2).gsheet',
#  'products (1) (1).gsheet',
#  'products (1).gsheet',
#  'products (2) (1).gsheet',
#  'products (2).gsheet',
#  'ödev.gsheet',
#  'Satışlarda Ödeme Tercihleri ve Kategori Analizi.gsheet',
#  'W1D2 - E-posta Kampanyası.csv',
#  'W1D2 - E-posta Kampanyası.gsheet',
#  'E posta duzenleme.gsheet',
#  'Facebook Ads Data (2).gsheet',
#  'Facebook Ads Data (1).gsheet',
#  'Facebook Ads Data.gsheet',
#  'Google Ads Data.gsheet',
#  'gwz_finance_campaign (1).gsheet',
#  'gwz_finance_campaign.gsheet',
#  'Copy of gwz_finance_orders.gsheet',
#  'Copy of gwz_finance_shipping .gsheet',
#  ' Greenweez Finans Raporu Deniz.gsheet',
#  'Copy of Quality Products - Sales.gsheet',
#  'Copy of Quality Products - Refund reason.gsheet',
#  'Copy of Quality Products at Greenweez.gsheet',
#  'Copy of Media at Greenweez (2).gsheet',
#  'Copy of Media at Greenweez (1).gsheet',
#  'Copy of Media at Greenweez.gsheet',
#  'deniz CRM at Greenweez.gsheet',
#  '"DENİZ-Challenge 1 SQL".gsheet',
#  'results-20250930-155318 (1).gsheet',
#  'results-20250930-155318.gsheet',
#  'results-20251003-024541.gsheet',
#  'results-20251003-024801.gsheet',
#  'results-20251003-025144.gsheet',
#  'results-20251003-030224.gsheet',
#  'results-20251003-030346.gsheet',
#  'results-20251007-145247.gsheet',
#  'results-20251007-144214.gsheet',
#  'results-20251007-151253.gsheet',
#  'results-20251007-154637.gsheet',
#  'results-20251009-160441.gsheet',
#  'results-20251009-160535.gsheet',
#  'results-20251010-134255.gsheet',
#  'results-20251010-135247.gsheet',
#  'Copy of 15 - circle_parcel (2).gsheet',
#  'Copy of 15 - circle_parcel (1).gsheet',
#  'results-20251011-192956.gsheet',
#  'Copy of 15 - circle_parcel.gsheet',
#  'results-20251011-194819.gsheet',
#  'results-20251011-192638.gsheet',
#  'results-20251011-194953.gsheet',
#  'results-20251011-195935.gsheet',
#  'results-20251011-201456.gsheet',
#  'results-20251011-201614.gsheet',
#  'results-20251011-201724.gsheet',
#  'results-20251011-202801.gsheet',
#  'Parcel_kpi_month.gsheet',
#  'results-20251011-203244.gsheet',
#  'parcel_delay.gsheet',
#  'delay_rate.gsheet',
#  'category_1.gsheet',
#  'cat2_cat3.gsheet',
#  'results1.gsheet',
#  'solution (1).gsheet',
#  'pdt_name.gsheet',
#  'stock_info.gsheet',
#  'results-20251012-151234.gsheet',
#  'add_price.gsheet',
#  'add_category.gsheet',
#  'last_3month.gsheet',
#  'solution.gsheet',
#  'results-20251012-153451 (2).gsheet',
#  'results-20251012-153451 (1).gsheet',
#  'results-20251012-153451.gsheet',
#  'results-20251012-161749.gsheet',
#  'olist_orders_dataset (2).gsheet',
#  'olist_order_items_dataset (2).gsheet',
#  'olist_order_items_dataset (1).gsheet',
#  'olist_order_reviews_dataset (2).gsheet',
#  'olist_order_reviews_dataset (1).gsheet',
#  'olist_products_dataset (2).gsheet',
#  'olist_order_payments_dataset (1).gsheet',
#  'olist_products_dataset (1).gsheet',
#  'olist_customers_dataset (1).gsheet',
#  'olist_geolocation_dataset (3).gsheet',
#  'olist_geolocation_dataset (2).gsheet',
#  'olist_geolocation_dataset (1).gsheet',
#  'olist_sellers_dataset (1).gsheet',
#  'product_category_name_translation (1).gsheet',
#  'olist_orders_dataset (1).gsheet',
#  'olist_orders_dataset.gsheet',
#  'olist_order_items_dataset.gsheet',
#  'olist_order_reviews_dataset.gsheet',
#  'olist_products_dataset.gsheet',
#  'olist_order_payments_dataset.gsheet',
#  'olist_customers_dataset.gsheet',
#  'olist_geolocation_dataset.gsheet',
#  'olist_sellers_dataset.gsheet',
#  'product_category_name_translation.gsheet',
#  'bq-results-20251102-172536-1762104482440',
#  'bq-results-20251102-173216-1762104800578',
#  'Müşteri başına sipariş sayısı (1).gsheet',
#  'Müşteri başına sipariş sayısı.gsheet',
#  'En çok sipariş verilen 10 ürün.gsheet',
#  'kategori_bazinda_gelir.gsheet',
#  'Eyalet Bazında Toplam Gelir Analizi.gsheet',
#  ' Satıcı ve Müşteri Şehir Dağılımı.gsheet',
#  'aylık toplam gelir.gsheet',
#  ' Müşteri Eyaletine Göre Ortalama Sipariş Değeri (AOV).gsheet',
#  'DENİZ Challenge - Greenweez - parcel data.gsheet',
#  'Copy of funnel - Greenweez.gsheet',
#  'B2B.gsheet',
#  'Copy of 15 - circle_funnel.gsheet',
#  'nps_global.gsheet',
#  'nps_domain (1).gsheet',
#  'nps_domain.gsheet',
#  'transporter.gsheet',
#  'orders_nps.gsheet',
#  'Copy of NPS at Greenweez.gsheet',
#  '10-gwz_finance',
#  'Copy of KPI Framework _ Tracking _ Template.gsheet',
#  'Untitled form.gform',
#  'Circle Potansiyel Müşteri Takibi.gsheet',
#  'İADE FORMU.gform',
#  'Copy of  Supply.gsheet',
#  'Copy of Finance.gsheet',
#  'Claims Tracker.gsheet',
#  'Copy of Delivery updates.gsheet',
#  'Copy of 19 - Exercise 2 - Metrics & Dimensions.gsheet',
#  'Copy of Demo-tables.gsheet',
#  'github-issue-tracker-<ndenizkoroglu>.gsheet']

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/Colab Notebooks/data.zip"
extract_path = "/content/drive/MyDrive/Colab Notebooks/olist"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as z:
    z.extractall(extract_path)

os.listdir(extract_path)
# Out:
# ['data', '__MACOSX']

# %%
data_path = "/content/drive/MyDrive/Colab Notebooks/olist/data"
os.listdir(data_path)
# Out:
# ['olist_sellers_dataset.csv',
#  'olist_orders_dataset.csv',
#  'olist_order_items_dataset.csv',
#  'olist_customers_dataset.csv',
#  'olist_order_payments_dataset.csv',
#  'olist_order_reviews_dataset.csv',
#  'olist_products_dataset.csv']

# %%
import pandas as pd

orders = pd.read_csv(
    f"{data_path}/olist_orders_dataset.csv",
    parse_dates=[
        "order_purchase_timestamp",
        "order_delivered_customer_date",
        "order_estimated_delivery_date"
    ]
)

order_items = pd.read_csv(f"{data_path}/olist_order_items_dataset.csv")
payments = pd.read_csv(f"{data_path}/olist_order_payments_dataset.csv")
reviews = pd.read_csv(f"{data_path}/olist_order_reviews_dataset.csv")
products = pd.read_csv(f"{data_path}/olist_products_dataset.csv")
customers = pd.read_csv(f"{data_path}/olist_customers_dataset.csv")

# %%
orders["order_status"].value_counts(normalize=True)
# Out:
# order_status
# delivered      0.970203
# shipped        0.011132
# canceled       0.006285
# unavailable    0.006124
# invoiced       0.003158
# processing     0.003027
# created        0.000050
# approved       0.000020
# Name: proportion, dtype: float64

# %% [markdown]
# *Siparişlerin büyük çoğunluğu teslim edilmiş olduğu için analiz teslim edilen siparişler üzerinden devam edilmiştir.*

# %%
orders_delivered = orders[orders["order_status"] == "delivered"].copy()

# %% [markdown]
# *Teslimat süresi ve müşteri memnuniyeti analizleri için yalnızca teslim edilen siparişler seçilmiştir.*

# %%
orders_delivered["delivery_days"] = (
    orders_delivered["order_delivered_customer_date"] -
    orders_delivered["order_purchase_timestamp"]
).dt.days

orders_delivered["delivery_days"].describe()
# Out:
# count    96470.000000
# mean        12.093604
# std          9.551380
# min          0.000000
# 25%          6.000000
# 50%         10.000000
# 75%         15.000000
# max        209.000000
# Name: delivery_days, dtype: float64

# %% [markdown]
#  *Teslimat süresi, sipariş tarihi ile müşteriye teslim tarihi arasındaki gün farkı olarak hesaplanmıştır.
# Siparişlerin yarısı yaklaşık 10 gün içinde müşteriye ulaşmaktadır.*

# %%
orders_delivered["delivery_delay"] = (
    orders_delivered["order_delivered_customer_date"] -
    orders_delivered["order_estimated_delivery_date"]
).dt.days

# %%
orders_delivered.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'delivery_days', 'delivery_delay'],
#       dtype='object')

# %% [markdown]
# *Teslimat gecikmesi, tahmini teslim tarihi ile gerçek teslim tarihi arasındaki fark olarak hesaplanmıştır. Pozitif değerler teslimatın geciktiğini, negatif değerler ise tahmini tarihten erken teslim edildiğini göstermektedir.*

# %%
(
    (orders_delivered["delivery_delay"] > 0)
    .value_counts(normalize=True)
    .rename({False: "Zamanında / Erken", True: "Gecikmiş"})
    * 100
).round(2)
# Out:
# delivery_delay
# Zamanında / Erken    93.23
# Gecikmiş              6.77
# Name: proportion, dtype: float64

# %% [markdown]
# *Siparişlerin yaklaşık %93’ü zamanında veya erken teslim edilirken, %7’sinde gecikme yaşanmıştır.*

# %%
orders_reviews = orders_delivered.merge(
    reviews[["order_id", "review_score"]],
    on="order_id",
    how="left"
)

# %% [markdown]
# *Müşteri memnuniyetini analiz edebilmek için siparişler ile yorum puanları birleştirilmiştir.*

# %%
orders_reviews = orders_reviews.dropna(subset=["review_score"])

# %% [markdown]
# *Yorum puanı bulunmayan siparişler, memnuniyet analizlerinde analiz dışı bırakılmıştır.*

# %%
orders_reviews["gecikme_durumu"] = orders_reviews["delivery_delay"] > 0

orders_reviews.groupby("gecikme_durumu")["review_score"].mean().rename({
    False: "Zamanında / Erken",
    True: "Gecikmiş"
})
# Out:
# gecikme_durumu
# Zamanında / Erken    4.289999
# Gecikmiş             2.271025
# Name: review_score, dtype: float64

# %% [markdown]
# *Gecikmiş grubun ortalamasının daha düşük olduğu görülmektedir.*

# %%
import matplotlib.pyplot as plt

mean_scores = (
    orders_reviews
    .groupby("gecikme_durumu")["review_score"]
    .mean()
    .rename({False: "Zamanında / Erken", True: "Gecikmiş"})
)

plt.figure(figsize=(5,4))
mean_scores.plot(kind="bar")
plt.ylabel("Ortalama Memnuniyet Puanı")
plt.title("Teslimat Gecikmesi ve Müşteri Memnuniyeti")
plt.xticks(rotation=0)
plt.show()

# %%
from scipy.stats import ttest_ind

on_time = orders_reviews.loc[
    orders_reviews["gecikme_durumu"] == False, "review_score"
]

delayed = orders_reviews.loc[
    orders_reviews["gecikme_durumu"] == True, "review_score"
]

ttest_ind(on_time, delayed, equal_var=False)
# Out:
# TtestResult(statistic=np.float64(100.96653430713094), pvalue=np.float64(0.0), df=np.float64(6905.583486777538))

# %% [markdown]
# H0: Teslimat gecikmesi müşteri memnuniyetini etkilemez.
# H1: Teslimat gecikmesi müşteri memnuniyetini etkiler.
#
# Yapılan t-testi sonucunda iki grup arasında istatistiksel olarak anlamlı bir fark bulunmuştur (p < 0.05).

# %%
orders_reviews_items = (
    orders_reviews
    .merge(order_items, on="order_id", how="inner")
    .merge(products, on="product_id", how="inner")
)

# %%
orders_reviews_items = orders_reviews_items.dropna(subset=["product_category_name"])

# %%
top_categories = (
    orders_reviews_items["product_category_name"]
    .value_counts()
    .head(10)
    .index
)

category_scores = (
    orders_reviews_items[
        orders_reviews_items["product_category_name"].isin(top_categories)
    ]
    .groupby("product_category_name")["review_score"]
    .mean()
    .sort_values(ascending=False)
)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
category_scores.plot(kind="bar")
plt.ylabel("Ortalama Memnuniyet Puanı")
plt.title("Ürün Kategorisine Göre Ortalama Müşteri Memnuniyeti")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
category_scores.round(3)
# Out:
# product_category_name
# beleza_saude              4.191
# esporte_lazer             4.166
# automotivo                4.116
# utilidades_domesticas     4.108
# ferramentas_jardim        4.081
# relogios_presentes        4.072
# telefonia                 3.995
# informatica_acessorios    3.985
# moveis_decoracao          3.950
# cama_mesa_banho           3.921
# Name: review_score, dtype: float64

# %% [markdown]
# En yüksek ortalama memnuniyet beleza_saude kategorisinde, en düşük ise cama_mesa_banho kategorisinde gözlemlenmiştir.
